# %%
import numpy as np
import pandas as pd
import mne
import os
import matplotlib.pyplot as pl
from   matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline
# %matplotlib notebook
from jumeg.base.jumeg_base import jumeg_base as jb

# %%
p="/home/fboers/MEGBoers/data/exp/QUATERS/mne/210857/QUATERS01/191210_1325/1/"
f="210857_QUATERS01_191210_1325_1_c,rfDC,meeg,nr,bcc,int-raw.fif"
f="210857_QUATERS01_191210_1325_1_c,rfDC,meeg,nr,bcc,int,fibp0.10-45.0-raw.fif"
fraw=os.path.join(p,f)

# %%
raw,raw_fname = jb.get_raw_obj(fraw,raw=None)
# Out:
# Opening raw data file /home/fboers/MEGBoers/data/exp/QUATERS/mne/210857/QUATERS01/191210_1325/1/210857_QUATERS01_191210_1325_1_c,rfDC,meeg,nr,bcc,int,fibp0.10-45.0-raw.fif...
#     Range : 0 ... 403362 =      0.000 ...   396.522 secs
# Ready.
# Current compensation grade : 0
# Reading 0 ... 403362  =      0.000 ...   396.522 secs...

# %%
anna = raw.annotations
print(anna)
# Out:
# <Annotations  |  629 segments : ECG (509), EOG ver (64), EOG hor (56), orig_time : 2019-12-10 12:56:35>

# %%
t0=0.0
t1=132.0

raw_crop=raw.copy().crop(tmin=t0,tmax=t1)

# %%
anna_cr = raw_crop.annotations
print(anna_cr)
# Out:
# <Annotations  |  210 segments : ECG (169), EOG ver (19), EOG hor (22), orig_time : 2019-12-10 12:56:35>

# %%
print(anna_cr[0])
# Out:
# OrderedDict([('onset', 0.11698205769062042), ('duration', 0.0009830445051193237), ('description', 'ECG'), ('orig_time', 1575982595.0)])

# %%
evts= mne.events_from_annotations(raw_crop,event_id={ "ECG":999},use_rounding=True,chunk_duration=None)
onsets=evts[0][:,0]  #,:,0]
print(onsets.shape)
print(" {} ".format(onsets/1024.17))
# Out:
# Used Annotations descriptions: ['ECG']
# (169,)
#  [1.16191648e-01 8.84618764e-01 1.72822871e+00 2.56012185e+00
#  3.31780857e+00 4.08428288e+00 4.86345040e+00 5.64261792e+00
#  6.37491823e+00 7.09452532e+00 7.83268403e+00 8.57084273e+00
#  9.30411943e+00 1.00022457e+01 1.07062304e+01 1.14375543e+01
#  1.21766894e+01 1.28865325e+01 1.35758712e+01 1.43111007e+01
#  1.50805042e+01 1.58567425e+01 1.65870900e+01 1.73262251e+01
#  1.80985579e+01 1.88874894e+01 1.96402941e+01 2.03296328e+01
#  2.10609567e+01 2.18059502e+01 2.25411797e+01 2.32695744e+01
#  2.39745355e+01 2.47195290e+01 2.54889325e+01 2.62270912e+01
#  2.69545095e+01 2.77131726e+01 2.84767177e+01 2.92129236e+01
#  2.99237431e+01 3.06697130e+01 3.14361874e+01 3.21753225e+01
#  3.28754015e+01 3.36116074e+01 3.43692942e+01 3.51465089e+01
#  3.58641632e+01 3.65720535e+01 3.73248582e+01 3.80923089e+01
#  3.88128924e+01 3.95471455e+01 4.02911626e+01 4.10625189e+01
#  4.18084888e+01 4.25114971e+01 4.32506322e+01 4.40132009e+01
#  4.47591708e+01 4.54846363e+01 4.62550163e+01 4.70517590e+01
#  4.78680297e+01 4.86042356e+01 4.93365359e+01 5.01196090e+01
#  5.09085406e+01 5.16506049e+01 5.23829052e+01 5.31435211e+01
#  5.39402638e+01 5.47409122e+01 5.54839529e+01 5.62582384e+01
#  5.70520519e+01 5.78468418e+01 5.85947645e+01 5.93710029e+01
#  6.01696984e+01 6.09840163e+01 6.17514670e+01 6.25218470e+01
#  6.33166369e+01 6.41143560e+01 6.48730191e+01 6.56385170e+01
#  6.64333070e+01 6.72388373e+01 6.79984768e+01 6.87786207e+01
#  6.95939151e+01 7.04277610e+01 7.19753557e+01 7.27506176e+01
#  7.35375963e+01 7.42777078e+01 7.50158665e+01 7.57960104e+01
#  7.66015408e+01 7.74129295e+01 7.81764746e+01 7.89595477e+01
#  7.97660545e+01 8.05725612e+01 8.13419647e+01 8.21377310e+01
#  8.29383794e+01 8.37546501e+01 8.45289356e+01 8.53286076e+01
#  8.61673355e+01 8.70021578e+01 8.77910894e+01 8.85722097e+01
#  8.93816456e+01 9.02047512e+01 9.10093051e+01 9.17660154e+01
#  9.25285841e+01 9.33116572e+01 9.41259752e+01 9.49188123e+01
#  9.56940742e+01 9.65064394e+01 9.73285685e+01 9.81214056e+01
#  9.88712811e+01 9.96543543e+01 1.00469649e+02 1.01291778e+02
#  1.02070945e+02 1.02852066e+02 1.03659549e+02 1.04483631e+02
#  1.05299901e+02 1.06059541e+02 1.06860189e+02 1.07670602e+02
#  1.08466368e+02 1.09214291e+02 1.09997364e+02 1.10790201e+02
#  1.11598660e+02 1.12364158e+02 1.13135515e+02 1.13939092e+02
#  1.14764150e+02 1.15567728e+02 1.16333226e+02 1.17128016e+02
#  1.17941357e+02 1.18752746e+02 1.19516291e+02 1.20306199e+02
#  1.21111729e+02 1.21916283e+02 1.22660301e+02 1.23417011e+02
#  1.24186414e+02 1.24966558e+02 1.25712528e+02 1.26475097e+02
#  1.27263052e+02 1.28065653e+02 1.28830175e+02 1.29591767e+02
#  1.30369958e+02]

# %%
ep = mne.Epochs(raw_crop,evts[0],event_id=999,tmin=-0.4,tmax=0.4)
print(ep)
# Out:
# 169 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# <Epochs  |   169 events (good & bad), -0.400098 - 0.400098 sec, baseline [None, 0], ~3.7 MB, data not loaded,
#  '999': 169>

# %%
avg=ep.average()
print(avg)
# Out:
# <Evoked  |  '999' (average, N=168), [-0.4001, 0.4001] sec, 271 ch, ~5.4 MB>

# %%
avg.plot()

# %%
t0=200.0
t1=300.0

raw_crop1=raw.copy().crop(tmin=t0,tmax=t1)

# %%
anna_cr1 = raw_crop1.annotations
print(anna_cr1)
# Out:
# <Annotations  |  160 segments : ECG (128), EOG hor (18), EOG ver (14), orig_time : 2019-12-10 12:56:35>

# %%
evts1= mne.events_from_annotations(raw_crop1,event_id={ "ECG":999},use_rounding=True,chunk_duration=None)
onsets1=evts1[0][:,0]  #,:,0]
print(onsets1.shape)
print(" {} ".format(onsets1/1024.17))
# Out:
# Used Annotations descriptions: ['ECG']
# (169,)
#  [131.16474804 131.93610436 132.65571145 133.39972856 134.15350967
#  134.93462999 135.6874347  136.45781462 137.25846295 138.07766289
#  138.86268881 139.66919554 140.49230108 141.33786383 142.09750334
#  142.87471806 143.67243719 144.47406192 145.26396985 145.99236455
#  146.74028726 147.50969077 148.28690549 149.031899   149.77591611
#  150.55801283 151.36256676 152.17102629 152.94140621 153.74205454
#  154.56711288 155.39314762 156.17719715 156.94757706 157.74822539
#  158.56254333 159.37197926 160.12966597 160.89906949 161.68897742
#  162.49450775 163.27269887 164.0713944  164.89547634 165.73518068
#  166.53094701 167.31109093 168.11564486 168.9367976  169.76087954
#  170.49708544 171.28211137 172.0788541  172.87754963 173.63230714
#  174.41440386 175.21798139 176.02155892 176.77924563 177.53986155
#  178.34636828 179.16849742 179.96035814 180.71902126 181.49721238
#  182.2783327  183.05066542 183.79663532 184.58849605 185.39304998
#  186.20736792 186.98946464 187.74129295 188.52729527 189.3201324
#  190.07781911 190.82867102 191.60783854 192.40751047 193.1954656
#  193.9433883  194.71279182 195.49781775 196.29358407 197.04443598
#  197.80114629 198.58519582 199.37998574 200.15134206 200.90512317
#  201.7038187  202.53180624 203.35198258 204.1145513  204.89274242
#  205.67972114 206.46279426 207.20095297 207.93032407 208.69679838
#  209.48377711 210.29418944 211.05968736 211.84178408 212.65122001
#  213.46163235 214.23689427 215.00727418 215.7835125  216.57537323
#  217.35649355 218.09855786 218.86893777 219.64615249 220.43117842
#  221.18203033 221.92995304 222.69349815 223.48242967 224.18641436
#  224.92457307 225.65101497 226.41944208 227.21813761 227.97387153
#  228.71593583 229.48143375 230.25279006 231.03391039 231.76621069
#  232.50046379 233.2532685  234.04024722 234.83698995 235.59467667
#  236.36310378 237.15203531 237.96342404 238.74747356 239.51882988
#  240.31264341 241.11719734 241.89148286 242.63354717 243.41466749
#  244.22117422 245.02475175 245.79220247 246.55477118 247.3202691
#  248.09357821 248.84540652 249.56501362 250.31977113 251.11358466
#  251.9327846  252.71683412 253.51064765 254.32008358 255.15685872
#  255.91356904 256.67125575 257.44065927 258.23056719 259.02242792
#  259.76937422 260.53389574 261.32770927 262.1400744 ]

# %%
ep = mne.Epochs(raw_crop,evts1[0],event_id=999,tmin=-0.4,tmax=0.4)
print(ep)
# Out:
# 169 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# <Epochs  |   169 events (good & bad), -0.400098 - 0.400098 sec, baseline [None, 0], ~3.7 MB, data not loaded,
#  '999': 169>

# %%
ep.plot(block=True)
# Out:
# Loading data for 54 events and 815 original time points ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-921d07b5a86a> in <module>()
# ----> 1 ep.plot(block=True)
#
# /home/fboers/MEGBoers/megtools/python/mne-python/mne/epochs.py in plot(self, picks, scalings, n_epochs, n_channels, title, events, event_colors, order, show, block, decim, noise_cov, butterfly, show_scrollbars)
#    1033                            show=show, block=block, decim=decim,
#    1034                            noise_cov=noise_cov, butterfly=butterfly,
# -> 1035                            show_scrollbars=show_scrollbars)
#    1036
#    1037     @copy_function_doc_to_method_doc(plot_epochs_psd)
#
# /home/fboers/MEGBoers/megtools/python/mne-python/mne/viz/epochs.py in plot_epochs(epochs, picks, scalings, n_epochs, n_channels, title, events, event_colors, order, show, block, decim, noise_cov, butterfly, show_scrollbars)
#     850     _prepare_mne_browse_epochs(params, projs, n_channels, n_epochs, scalings,
#     851                                title, picks, events=events, order=order,
# --> 852                                event_colors=event_colors, butterfly=butterfly)
#     853     _prepare_projectors(params)
#     854
#
# /home/fboers/MEGBoers/megtools/python/mne-python/mne/viz/epochs.py in _prepare_mne_browse_epochs(params, projs, n_channels, n_epochs, scalings, title, picks, events, event_colors, order, butterfly, info)
#    1168     params['callback_key'] = callback_key
#    1169     # Draw event lines for the first time.
# -> 1170     _plot_vert_lines(params)
#    1171
#    1172
#
# /home/fboers/MEGBoers/megtools/python/mne-python/mne/viz/epochs.py in _plot_vert_lines(params)
#    1413     for epoch_idx in range(len(epochs.events)):
#    1414         pos = [epoch_idx * len(epochs.times), epoch_idx * len(epochs.times)]
# -> 1415         ax.plot(pos, ax.get_ylim(), color='black', linestyle='--', zorder=2)
#    1416     if params['events'] is not None:
#    1417         _draw_event_lines(params)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1898         self._set_artist_props(line)
#    1899         if line.get_clip_path() is None:
# -> 1900             line.set_clip_path(self.patch)
#    1901
#    1902         self._update_line_limits(line)
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     759         # will be hit at least once.
#     760         self.pchanged()
# --> 761         self.stale = True
#     762
#     763     def get_alpha(self):
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in stale(self, val)
#     228
#     229         if val and self.stale_callback is not None:
# --> 230             self.stale_callback(self, val)
#     231
#     232     def get_window_extent(self, renderer):
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in _stale_axes_callback(self, val)
#      49 def _stale_axes_callback(self, val):
#      50     if self.axes:
# ---> 51         self.axes.stale = val
#      52
#      53
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in stale(self, val)
#     228
#     229         if val and self.stale_callback is not None:
# --> 230             self.stale_callback(self, val)
#     231
#     232     def get_window_extent(self, renderer):
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in _stale_figure_callback(self, val)
#      49 def _stale_figure_callback(self, val):
#      50     if self.figure:
# ---> 51         self.figure.stale = val
#      52
#      53
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in stale(self, val)
#     228
#     229         if val and self.stale_callback is not None:
# --> 230             self.stale_callback(self, val)
#     231
#     232     def get_window_extent(self, renderer):
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in _auto_draw_if_interactive(fig, val)
#     587     """
#     588     if val and matplotlib.is_interactive() and not fig.canvas.is_saving():
# --> 589         fig.canvas.draw_idle()
#     590
#     591
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1912         if not self._is_idle_drawing:
#    1913             with self._idle_draw_cntx():
# -> 1914                 self.draw(*args, **kwargs)
#    1915
#    1916     def draw_cursor(self, event):
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1206
#    1207         for tick in ticks_to_draw:
# -> 1208             tick.draw(renderer)
#    1209
#    1210         # scale up the axis label box to also find the neighbors, not
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     295         for artist in [self.gridline, self.tick1line, self.tick2line,
#     296                        self.label1, self.label2]:
# --> 297             artist.draw(renderer)
#     298         renderer.close_group(self.__name__)
#     299         self.stale = False
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/text.py in draw(self, renderer)
#     675             posx = float(textobj.convert_xunits(textobj._x))
#     676             posy = float(textobj.convert_yunits(textobj._y))
# --> 677             posx, posy = trans.transform_point((posx, posy))
#     678             if not np.isfinite(posx) or not np.isfinite(posy):
#     679                 _log.warning("posx and posy should be finite values")
#
# KeyboardInterrupt:

# %%
raw_crop.times[-1]
# Out:
# 132.0

# %%
avg=ep.average()

# %%
avg.plot()

# %%
print(anna_cr1[0])
# Out:
# OrderedDict([('onset', 132.05702209472656), ('duration', 0.0009765625), ('description', 'ECG'), ('orig_time', 1575982595.0)])
